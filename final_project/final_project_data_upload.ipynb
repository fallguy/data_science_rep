# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

# %%
# data = pd.read_excel("data_test-1.xls", header=26, skiprows=0)
data = pd.read_excel("python_data.xls")

# %%
data.head()
# Out:
#    Lease         Space      Product Category                Space Type  \
# 0  45252  0112230 G011  SF21 US Food Service  In-Line Units 0-9,999 SF
# 1  62599  0112229 9270  SF21 US Food Service          Kiosk 0-9,999 SF
# 2  37247  0112234 1000  SF21 US Food Service  In-Line Units 0-9,999 SF
# 3  27469  0112243 O358    SF11 US Food Court     Food Court 0-9,999 SF
# 4  86698  0112247 0584    SF11 US Food Court     Food Court 0-9,999 SF
#
#    Unnamed: 4                     Unnamed: 5  Shop Count 2014  Area 2014  \
# 0         NaN  12230 G011 Hot Dog on a Stick                1        532
# 1         NaN  12229 9270 Hot Dog on a Stick                1        260
# 2         NaN  12234 1000 Hot Dog on a Stick                0          0
# 3         NaN  12243 O358 Hot Dog on a Stick                0          0
# 4         NaN  12247 0584 Hot Dog on a Stick                1        555
#
#        MAT $  MAT $ (Last Year)    ...      Forecasted Sales-Calc  \
# ...

# %%
# merchant_types.sort()  #revise sort function largest to smallest
# merchant_types
# merchant_types.sort?

data.shape
# Out:
# (2561, 154)

# %%
# merchant_types = data.groupby(['merchant_type'])['2015_area'].sum()
# merchant_types.sort(ascending=False)  #revise sort function largest to smallest
# plt.xticks(np.arange(len(merchant_types)), rotation='vertical')
# merchant_types[:10].plot(color='r', marker='o', figsize=(50, 20))

# %%
data['merchant_type'].plot
# Out:
# <bound method Series.plot_series of 0                     S132 US Teens Fashion
# 1                     S132 US Teens Fashion
# 2                    S131 US Unisex Fashion
# 3                      S231 US Family Shoes
# 4                     S132 US Teens Fashion
# 5                   S521 US Beauty & Health
# 6                      SF21 US Food Service
# 7                     S211 US Women's Shoes
# 8                     S211 US Women's Shoes
# 9                          Z111 US Not used
# 10                  S111 US Women's Fashion
# 11                  S111 US Women's Fashion
# 12              S153 US Fashion Accessories
# 13        S472 US Gifts, Cards & Stationery
# 14        S472 US Gifts, Cards & Stationery
# 15                   S131 US Unisex Fashion
# 16                  S521 US Beauty & Health
# 17                  S111 US Women's Fashion
# 18                       SF31 US Restaurant
# 19                       SF31 US Restaurant
# ...
